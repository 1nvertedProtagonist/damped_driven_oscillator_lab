# %%
## nice. now, find the constant of proportionality between voltage signal and the displacement/
## amplitude angle. this will be useful for later. 

## this will be done run by run for all the amplitude calibration runs at the recorded initial
## release angles

raw_01rad = np.genfromtxt("0.1_rad.csv",delimiter=",", comments="%",skip_header=0)
raw_02rad = np.genfromtxt("0.2_rad.csv",delimiter=",", comments="%",skip_header=0)
raw_04rad = np.genfromtxt("0.4_rad.csv",delimiter=",",comments="%",skip_header=0)
raw_005rad = np.genfromtxt("0.05_rad.csv",delimiter=",",comments="%",skip_header=0)
raw_05_rad = np.genfromtxt("0.5_rad.csv",delimiter=",",comments="%",skip_header=0) 


rawlist = [raw_01rad,raw_02rad,raw_04rad,raw_005rad,raw_05_rad]
## time to extract peaks and the minima using methodss from code above. 

#print(rawlist[i][:,2])

interests = []
raddispangorder = np.asarray([0.1,0.2,0.4,0.05,0.5])
for i in range(len(rawlist)): 
  interest = min((np.asarray(rawlist[i][:,2])))
  interests.append(interest)
arrints = np.asarray(interests)

a= arrints/raddispangorder
print(np.mean(a))
print(lbts.SEM(a))


## all below is basically overcomplicated garbage
'''
list_of_propconsMX= []
list_of_propconsMN= []
err_of_propconsMX=[]
err_of_propconsMN=[]
for i in range(len(rawlist)):
  rawxarr = np.asarray(rawlist[i][0:2339,0]) 
  rawyarr =np.asarray(rawlist[i][0:2339,2])
  plt.plot(rawxarr,rawyarr)
  plt.show()
  indofintMX = find_peaks(rawyarr,height=1.43,distance=80)[0]
  N=2339
  maskMX = np.zeros(N,dtype=bool)
  maskMX[indofintMX] = True

  finxMXarr = rawxarr[maskMX]
  finyMXarr = rawyarr[maskMX]
  print(finyMXarr[0])
  print(finyMXarr[0]-mean_offset)
  #print(f"period of this thing is {np.diff(finxMXarr)}")
  afrmrunMX = abs(finyMXarr[0:])/(raddispangorder[i]*np.exp(finbeta*finxMXarr[0:]))
  meanarunMX = np.mean(afrmrunMX)
  err_run_mx = lbts.SEM(afrmrunMX)
  list_of_propconsMX.append(meanarunMX)
  err_of_propconsMX.append(err_run_mx)

  indofintMN = argrelmin(rawyarr,order=100)[0]
  maskMN = np.zeros(N,dtype=bool)
  maskMN[indofintMN] = True
  
  finxMNarr = rawxarr[maskMN]
  #print(f"period of this thing is {np.diff(finxMNarr)}")
  finyMNarr = rawyarr[maskMN]
  print(abs(finyMNarr[0]-mean_offset))
  afrmrunMN = abs(finyMNarr[0:])/(raddispangorder[i]*np.exp(finbeta*finxMNarr[0:]))
  meanarunMN = np.mean(afrmrunMN)
  err_run_mn = lbts.SEM(afrmrunMN)
  list_of_propconsMN.append(meanarunMN)
  err_of_propconsMN.append(err_run_mn)

print(rawlist[4][0,2])
#print(list_of_propconsMX)
#print(err_of_propconsMX)
#print(list_of_propconsMN)
#print(err_of_propconsMN)

'''

#for i in range(len(rawlist)):
  #print(f"time array has shape{rawlist[i][:,0].shape}")
  #print(f"signal array has shape{rawlist[i][:,2].shape}")
#for i in range(len(lisfinymxvals)):

#######################################################
## UNABLE TO FIND PROPER PROPORTIONALITY CONSTANT FROM COLLECTED DATA
## VALUES MAKE NO SENSE AND HAVE HUGE UNCERTAINTY
## COLLECTED WRONG KIND OF DATA LOL, EVEN THOUGH HAD RIGHT PLAN,
## BRAIN BLANKED OUT IN LAB

# %%
## time to actually get to time domain analysis
## this is for broad sweep stuff! 

raw500 = np.genfromtxt("500mHz(in).csv",delimiter=",",comments="%",skip_header=0,usecols=(0,1,2),dtype=float,invalid_raise=False,autostrip=True)
raw550 = np.genfromtxt("550mHz(in).csv",delimiter=",", comments= "%",skip_header=0,usecols=(0,1,2),dtype=float,invalid_raise=False,autostrip=True)
raw600 = np.genfromtxt("600mHz(in).csv",delimiter=",", comments= "%",skip_header=0,usecols=(0,1,2),dtype=float,invalid_raise=False,autostrip=True)
raw650 = np.genfromtxt("650mHz(in).csv",delimiter=",", comments= "%",skip_header=0,usecols=(0,1,2),dtype=float,invalid_raise=False,autostrip=True)
raw700 = np.genfromtxt("700mHz(in).csv",delimiter=",", comments= "%",skip_header=0,usecols=(0,1,2),dtype=float,invalid_raise=False,autostrip=True)
raw750 = np.genfromtxt("750mHz(in).csv",delimiter=",", comments= "%",skip_header=0,usecols=(0,1,2),dtype=float,invalid_raise=False,autostrip=True)
raw800 = np.genfromtxt("800mHz(in).csv",delimiter=",", comments= "%",skip_header=0,usecols=(0,1,2),dtype=float,invalid_raise=False,autostrip=True)
raw850 = np.genfromtxt("850mHz(in).csv",delimiter=",", comments= "%",skip_header=0,usecols=(0,1,2),dtype=float,invalid_raise=False,autostrip=True)
raw900 = np.genfromtxt("900mHz(in).csv",delimiter=",", comments= "%",skip_header=0,usecols=(0,1,2),dtype=float,invalid_raise=False,autostrip=True)
raw950 = np.genfromtxt("950mHz(in).csv",delimiter=",", comments= "%",skip_header=0,usecols=(0,1,2),dtype=float,invalid_raise=False,autostrip=True)
raw1000 = np.genfromtxt("1000mHz(in).csv",delimiter=",", comments= "%",skip_header=0,usecols=(0,1,2),dtype=float,invalid_raise=False,autostrip=True)
raw1050= np.genfromtxt("1050mHz(in).csv",delimiter=",", comments= "%",skip_header=0,usecols=(0,1,2),dtype=float,invalid_raise=False,autostrip=True)
raw1100= np.genfromtxt("1100mHz(in).csv",delimiter=",", comments= "%",skip_header=0,usecols=(0,1,2),dtype=float,invalid_raise=False,autostrip=True)
raw1150= np.genfromtxt("1150mHz(in).csv",delimiter=",", comments= "%",skip_header=0,usecols=(0,1,2),dtype=float,invalid_raise=False,autostrip=True)
raw1200 = np.genfromtxt("1200mHz(in).csv",delimiter=",", comments= "%",skip_header=0,usecols=(0,1,2),dtype=float,invalid_raise=False,autostrip=True)


rawbroadruns=[raw500, raw550,raw600,raw650,raw700,raw750,raw800,raw850,raw900,raw950,raw1000,raw1050,raw1100,raw1150,raw1200]

#raw800 = np.genfromtxt("800mHz(in).csv",delimiter=",", comments= "%",skip_header=0,usecols=(0,1,2),dtype=float,invalid_raise=False,autostrip=True)
raw810 =np.genfromtxt("810mHz.csv",delimiter=",", comments= "%",skip_header=0,usecols=(0,1,2),dtype=float,invalid_raise=False,autostrip=True)
raw820 =np.genfromtxt("820mHz.csv",delimiter=",", comments= "%",skip_header=0,usecols=(0,1,2),dtype=float,invalid_raise=False,autostrip=True)
raw830 =np.genfromtxt("830mHz.csv",delimiter=",", comments= "%",skip_header=0,usecols=(0,1,2),dtype=float,invalid_raise=False,autostrip=True)
raw840 =np.genfromtxt("840mHz.csv",delimiter=",", comments= "%",skip_header=0,usecols=(0,1,2),dtype=float,invalid_raise=False,autostrip=True)
#raw850 =np.genfromtxt("850mHz(in).csv",delimiter=",", comments= "%",skip_header=0,usecols=(0,1,2),dtype=float,invalid_raise=False,autostrip=True)
raw860 =np.genfromtxt("860mHz.csv",delimiter=",", comments= "%",skip_header=0,usecols=(0,1,2),dtype=float,invalid_raise=False,autostrip=True)
raw870 =np.genfromtxt("870mHz.csv",delimiter=",", comments= "%",skip_header=0,usecols=(0,1,2),dtype=float,invalid_raise=False,autostrip=True)
raw880 =np.genfromtxt("880mHz.csv",delimiter=",", comments= "%",skip_header=0,usecols=(0,1,2),dtype=float,invalid_raise=False,autostrip=True)
raw890 =np.genfromtxt("890mHz.csv",delimiter=",", comments= "%",skip_header=0,usecols=(0,1,2),dtype=float,invalid_raise=False,autostrip=True)
#raw900 =np.genfromtxt("900mHz(in).csv",delimiter=",", comments= "%",skip_header=0,usecols=(0,1,2),dtype=float,invalid_raise=False,autostrip=True)

rawinc10runs = [raw800,raw810,raw820,raw830,raw840,raw850,raw860,raw870,raw880,raw890,raw900]

#raw860 =np.genfromtxt("810mHz.csv",delimiter=",", comments= "%",skip_header=0,usecols=(0,1,2),dtype=float,invalid_raise=False,autostrip=True)
raw861 =np.genfromtxt("861mHz.csv",delimiter=",", comments= "%",skip_header=0,usecols=(0,1,2),dtype=float,invalid_raise=False,autostrip=True)
raw862 =np.genfromtxt("862mHz (a bit too long).csv",delimiter=",", comments= "%",skip_header=0,usecols=(0,1,2),dtype=float,invalid_raise=False,autostrip=True)
raw863 =np.genfromtxt("863mHz.csv",delimiter=",", comments= "%",skip_header=0,usecols=(0,1,2),dtype=float,invalid_raise=False,autostrip=True)
raw864 =np.genfromtxt("864mHz.csv",delimiter=",", comments= "%",skip_header=0,usecols=(0,1,2),dtype=float,invalid_raise=False,autostrip=True)
raw865 =np.genfromtxt("865mHz.csv",delimiter=",", comments= "%",skip_header=0,usecols=(0,1,2),dtype=float,invalid_raise=False,autostrip=True)
raw866 =np.genfromtxt("866mHz.csv",delimiter=",", comments= "%",skip_header=0,usecols=(0,1,2),dtype=float,invalid_raise=False,autostrip=True)
raw867 =np.genfromtxt("867mHz.csv",delimiter=",", comments= "%",skip_header=0,usecols=(0,1,2),dtype=float,invalid_raise=False,autostrip=True)
raw868 =np.genfromtxt("868mHz.csv",delimiter=",", comments= "%",skip_header=0,usecols=(0,1,2),dtype=float,invalid_raise=False,autostrip=True)
raw869 =np.genfromtxt("869mHz.csv",delimiter=",", comments= "%",skip_header=0,usecols=(0,1,2),dtype=float,invalid_raise=False,autostrip=True)
#raw870 =np.genfromtxt("870mHz.csv",delimiter=",", comments= "%",skip_header=0,usecols=(0,1,2),dtype=float,invalid_raise=False,autostrip=True)
raw871 =np.genfromtxt("871mHz.csv",delimiter=",", comments= "%",skip_header=0,usecols=(0,1,2),dtype=float,invalid_raise=False,autostrip=True)
raw872 =np.genfromtxt("872mHz.csv",delimiter=",", comments= "%",skip_header=0,usecols=(0,1,2),dtype=float,invalid_raise=False,autostrip=True)
raw873 =np.genfromtxt("873mHz.csv",delimiter=",", comments= "%",skip_header=0,usecols=(0,1,2),dtype=float,invalid_raise=False,autostrip=True)
raw874 =np.genfromtxt("874mHz.csv",delimiter=",", comments= "%",skip_header=0,usecols=(0,1,2),dtype=float,invalid_raise=False,autostrip=True)
raw875 =np.genfromtxt("875mHz.csv",delimiter=",", comments= "%",skip_header=0,usecols=(0,1,2),dtype=float,invalid_raise=False,autostrip=True)

rawcloseruns = [raw860,raw861,raw862,raw863,raw864,raw865,raw866,raw867,raw868,raw869,raw870,raw871,raw872,raw873,raw874,raw875]


rawall = [rawbroadruns,rawinc10runs,rawcloseruns]

for i in range(len(rawall)): 
  for j in range(len(rawall[i])): 
    arr = rawall[i][j]           
    rawall[i][j] = (np.asarray(arr[:,0]), np.asarray(arr[:,1]), np.asarray(arr[:,2])-mean_offset)  

'''
for i in range(len(rawall)): 
  for j in range(len(rawall[i])): 
    plt.plot(rawall[i][j][0],rawall[i][j][1])
    plt.grid(True,alpha = 0.3, which = "both")
    plt.title(f"drive vs time type {i} run {j}")
    plt.show()
    plt.plot(rawall[i][j][0],rawall[i][j][2])
    plt.title(f"oscillator vs time type {i} run {j}")
    plt.grid(True,alpha = 0.3, which = "both")
    plt.show()
    plt.plot(rawall[i][j][0],rawall[i][j][1])
    plt.plot(rawall[i][j][0],rawall[i][j][2])
    plt.title(f"the together type {i} run {j}")
    plt.grid(True,alpha = 0.3, which = "both")
    plt.show()

#rawall = rawall[1:]
'''
#print(len(rawall))

#print(mean_offset)

#print(find_peaks(rawall[0][0][2],height=0))
#print(find_peaks(rawall[0][0][1],height=0))
## time to actually do the time domain analysis

lisfinamps = []
lisfinuncA = []
lisfinphis = []
lisfinuncP = []
lisfindrives = [np.asarray([500,550,600,650,700,750,800,850,900,950,1000,1050,1100,1150,1200]),
                np.asarray([800,810,820,830,840,850,860,870,880,890,900]),
                np.asarray([860,861,862,863,864,865,866,867,868,869,870,871,872,873,874,875])]

for i in range(len(rawall)): ##category list
  lisrnAs = []
  errs_lisrnAs = []
  lisrnphis = []
  errs_lisrnphis = []
  for j in range(len(rawall[i])): ##list of runs in category, only extracting 2 values of interest per run. 
                                  ## along with their uncs. be careful
    peaksA,propsA = find_peaks(rawall[i][j][2],height=0)
    peaksD,propsD = find_peaks(rawall[i][j][1],height=0)
    meanA = np.mean(propsA["peak_heights"])
    semA = lbts.SEM(propsA["peak_heights"])
    
    pks = lbts.match_peaks_one_to_one(peaksA/200,peaksD/200)
    print(pks)
    phirn = np.mean((abs(pks[0]-pks[1]))*(lisfindrives[i][j]*2*np.pi/1000))
    print(abs(pks[0]-pks[1]))
    unc_phirn = lbts.SEM(abs(pks[0]-pks[1]))

    lisrnAs.append(meanA)
    errs_lisrnAs.append(semA)
    lisrnphis.append(phirn)
    errs_lisrnphis.append(unc_phirn)

  arrnAs = np.asarray(lisrnAs)
  errs_arrnAs = np.asarray(errs_lisrnAs)
  arrnphis = np.asarray(lisrnphis)
  errs_arrnphis = np.asarray(errs_lisrnphis)

  lisfinamps.append(arrnAs)
  lisfinuncA.append(errs_arrnAs)
  lisfinphis.append(arrnphis)
  lisfinuncP.append(errs_arrnphis)


#print("Hello World!")
#print(lisfinamps[0].shape)
## time to test
plt.plot(lisfindrives[0],lisfinamps[0])
plt.show()

plt.plot(lisfindrives[0],lisfinphis[0])
plt.show()

plt.plot(lisfindrives[1],lisfinamps[1])
plt.show()

plt.plot(lisfindrives[1],lisfinphis[1])
plt.show()

plt.plot(lisfindrives[2],lisfinamps[2])
plt.show()

plt.plot(lisfindrives[2],lisfinphis[2])
plt.show()

plt.plot(lisfinphis[0],lisfinamps[0])
plt.show()
